# %% [markdown]
# # "python executes class body at definition time"
# - toc: false
# - badges: false
# - comments: true
# - categories: [python_notes]

# %%
class foo:
  print("hello batman")
# Out:
# hello batman

# %%
def foo_func():
  print("hello batman")

# %%
foo_func()
# Out:
# hello batman

# %% [markdown]
# - While executing class body, python evaluates various expressions** inside the class body and stores it in the local name space.
# - This is done because that namespace then forms the class attributes.
# - Class bodies are not the only such namespaces; set and dict comprehensions, and in Python 3, list comprehensions are also executed with a separate namespace, scoping their locals.
#
# ** These expressions could be anything that we write inside the class body such as class variable, instance variable, methods etc

# %% [markdown]
# Why does python behave differently for functions?
#
# Basically it fetches the instructions in the definition and stores it to the global variable(if the function is defined in the global scope) taking the value equal to its name.
